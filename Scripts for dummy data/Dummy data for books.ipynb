# %%
from faker import Faker
import random
# Create a Faker instance
fake = Faker()

for i in range(99,150):
    school_id = random.randint(1,8)
    #book_title = fake.t
    publisher = fake.name()
    ISBN = fake.isbn13()
    number_of_pages = random.randint(100,600)
    image = fake.image_url()
    language = fake.language_name()
    available_copies = random.randint(0,5)
    key_words = fake.words()
    output = '[' + ', '.join(key_words) + ']'
    book_titles = [
    "The Great Gatsby",
    "To Kill a Mockingbird",
    "1984",
    "Pride and Prejudice",
    "The Catcher in the Rye",
    "The Lord of the Rings",
    "Harry Potter and the Sorcerer's Stone",
    "The Chronicles of Narnia",
    "Moby-Dick",
    "The Hobbit",
    "The Great Gatsby",
    "The Alchemist",
    "Brave New World",
    "Animal Farm",
    "Gone with the Wind",
    "The Hunger Games",
    "The Da Vinci Code",
    "The Hitchhiker's Guide to the Galaxy",
    "The Shining",
    "The Picture of Dorian Gray",
    "Fahrenheit 451",
    "Jane Eyre",
    "The Odyssey",
    "The Divine Comedy",
    "The Girl with the Dragon Tattoo",
    "The Kite Runner",
    "The Handmaid's Tale",
    "The Book Thief",
    "The Color Purple",
    "The Sun Also Rises",
    "Catch-22",
    "The Adventures of Huckleberry Finn",
    "One Hundred Years of Solitude",
    "Beloved",
    "Frankenstein",
    "The Scarlet Letter",
    "The Grapes of Wrath",
    "War and Peace",
    "The Count of Monte Cristo",
    "Pride and Prejudice",
    "Don Quixote",
    "Wuthering Heights",
    "The Lord of the Flies",
    "The Outsiders",
    "A Tale of Two Cities",
    "The Secret Garden",
    "The Little Prince",
    "Crime and Punishment",
    "Les Misérables",
    "The Iliad"
]
   
    print("('"+book_titles[i-100]+"', '"+str(publisher)+"', '"+str(ISBN)+"', '"+str(number_of_pages)+"','"+str(image)+"','"+str(language)+"','"+str(available_copies)+"','Summary " + str(i+2) + "','"+str(output)+"','"+str(school_id)+"'),")
# Out:
# ('The Iliad', 'Danielle Montgomery', '978-1-86116-860-3', '579','https://placekitten.com/595/311','Italian','1','Summary 101','[only, health, take]','7'),
# ('The Great Gatsby', 'Hannah Smith', '978-0-526-87127-8', '225','https://placekitten.com/20/463','Slovenian','4','Summary 102','[recent, child, raise]','2'),
# ('To Kill a Mockingbird', 'Kevin Cannon', '978-0-448-56096-0', '324','https://picsum.photos/359/641','Twi','3','Summary 103','[daughter, player, raise]','3'),
# ('1984', 'Veronica Pitts', '978-0-457-14463-2', '104','https://placekitten.com/979/904','Latvian','5','Summary 104','[popular, ahead, book]','8'),
# ('Pride and Prejudice', 'Roger Adams', '978-0-284-49466-5', '564','https://placekitten.com/779/918','Yoruba','4','Summary 105','[allow, opportunity, call]','5'),
# ('The Catcher in the Rye', 'Erik Guerra', '978-0-596-10233-3', '403','https://placekitten.com/208/433','Croatian','3','Summary 106','[particular, crime, design]','6'),
# ...
